# %%
import numpy as np
import pandas as pd

# %%
src = pd.read_excel("../assets/source/ORDER_REPORT.xlsx", skiprows=1)
# Out:
# /Users/yuchewang/opt/miniconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
src
# Out:
#                                BSN  \
# 0     Bibiliographic System Number
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 3562                     007377413
# 3563                     004988629
# 3564                     004988629
# 3565                     004988629
# 3566                     008482881
#
#                                               Z13_TITLE        Z71_TEXT  \
# 0                                                 Title  Arrival or not
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# ...

# %%
src.head(10)
# Out:
#                             BSN              Z13_TITLE        Z71_TEXT  \
# 0  Bibiliographic System Number                  Title  Arrival or not
# 1                           NaN                    NaN             NaN
# 2                           NaN                    NaN             NaN
# 3                           NaN                    NaN             NaN
# 4                           NaN                    NaN             NaN
# 5                           NaN                    NaN             NaN
# 6                           NaN                    NaN             NaN
# 7                           NaN                    NaN             NaN
# 8                     004195893          Little rice :         Arrival
# 9                     005929081  R graphics cookbook :         Arrival
#
#         Z71_OPEN_DATE                        Z71_USER_NAME  \
# 0  Order Arrival Date  User who marked the item as Arrival
# 1                 NaN                      Shanghai Staff:
# ...

# %%
filtered = (src['BSN'].isna()) & (src['Z68_LIBRARY_NOTE'].isna())

# %%
filtered_df = src[src['BSN'].notna() & src['Z13_TITLE'].isna()]
filtered
# Out:
#    BSN Z13_TITLE Z71_TEXT Z71_OPEN_DATE    Z71_USER_NAME  \
# 1  NaN       NaN      NaN           NaN  Shanghai Staff:
# 2  NaN       NaN      NaN           NaN              HEW
# 3  NaN       NaN      NaN           NaN           ZHANGY
# 4  NaN       NaN      NaN           NaN        GENERICSH
# 5  NaN       NaN      NaN           NaN            QIAOZ
# 6  NaN       NaN      NaN           NaN           CHENVI
# 7  NaN       NaN      NaN           NaN              NaN
#
#                 Z71_DATA Z30_BARCODE Z30_ITEM_PROCESS_STATUS  \
# 1  2 new items reported:         NaN                      OR
# 2         Set or volumns         NaN                      GV
# 3                    NaN         NaN                      CT
# 4                    NaN         NaN                      LT
# 5                    NaN         NaN                      LB
# 6                    NaN         NaN                      PT
# 7                    NaN         NaN                 <blank>
#
# ...

# %%
filtered.shape[0]
# Out:
# 7

# %%
src = src[8:]

# %%
src
# Out:
#             BSN                                          Z13_TITLE Z71_TEXT  \
# 8     004195893                                      Little rice :  Arrival
# 9     005929081                              R graphics cookbook :  Arrival
# 10    005028983                       The secret lives of colour /  Arrival
# 11    005910617                                        B magazine.  Arrival
# 12    005910617                                        B magazine.  Arrival
# ...         ...                                                ...      ...
# 3562  007377413                                         Republic /  Arrival
# 3563  004988629                              HSK standard course =  Arrival
# 3564  004988629                              HSK standard course =  Arrival
# 3565  004988629                              HSK standard course =  Arrival
# 3566  008482881  Podcast Marketing: How to Easily Grow Your Aud...  Arrival
#
# ...

# %%
src = src.reset_index(drop=True)

# %%
src = src.drop_duplicates()

# %%
barcode_duplicates = src['Z30_BARCODE'].duplicated()
barcode_duplicates.name = 'barcode_duplicates'

# %%
barcode_duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3554    False
# 3555    False
# 3556    False
# 3557    False
# 3558    False
# Name: barcode_duplicates, Length: 3556, dtype: bool

# %%
src = src.join(barcode_duplicates)

# %%
src = src[src['barcode_duplicates'] == False]

# %%
src = src.drop(src.columns[-2:], axis=1)

# %%
src = src.reset_index(drop=True)

# %%
src.to_excel("OUTPUT_NYC_REPORT.xlsx", index=False)
